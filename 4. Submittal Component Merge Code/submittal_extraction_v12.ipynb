# %% [markdown]
# ## Step 1 - Load Libraries

# %%
import pdfplumber
import itertools
import json
import re
import spacy
from os import path
import csv
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2 - Load PDF/ Text Data

# %%
# data = ""
# # filename = "Data//"
# # with pdfplumber.open(file_name) as pdf:
# #     for index, page in enumerate(pdf.pages):
# #         data = data + str(page.extract_text())

# # print("Data present in PDF document.")
# # print(data)

pre_data = """
SECTION 210900
 WET FIRE PROTECTION SYSTEMS


 INDEX
 PAGE

 PART 1. - GENERAL

 This specification for the fire protection work is intended to be a performance type specification for the design,
 furnishing and complete installation of an automatic fire protection sprinkler system for complete coverage of all
 renovated and new spaces within the contract limits and to conform to the requirements of NFPA 13, this
 specification, owner’s insurance underwriter, AXA XL, and to the requirements of State and Local Codes and
 Regulations.

 1.1.
 SYSTEM DESCRIPTION

 Fire Protection System shall be a “Wet-Pipe” system employing automatic sprinklers attached to a piping system
 containing water and connected to a water supply so that water discharges immediately from the sprinkler head
 opened by fire.  Fire Protection System shall be approved by AXA XL formerly XLGAPS and the local Authority
 Having Jurisdiction.

 1.2.
 SUBMITTALS

 Product Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department
 connections specified and/or provided.

 PAGE : 1


 Shop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,”
 and consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction.
 Submit shop drawings showing piping materials, size, locations, and elevations. Include details of underground
 structures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and
 proximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic
 calculations.

 Hydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been
 approved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information,
 sprinkler system requirements, water supply information including water supply and sprinkler system demand
 curves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference
 points corresponding to reference points indicated on shop drawings.

 Maintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department
 connection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual.

 Test Reports and Certificates including “Contractor's Material & Test Certificate for Aboveground Piping” and
 “Contractor's Material & Test Certificate for Underground Piping” as described in NFPA 13.

 1.3.
 QUALITY ASSURANCE

 Regulatory Requirements:  Comply with the requirements of the following codes:

 FM DS 2-0 Installation Guidelines for Automatic Sprinklers
 FM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems
 FM DS 3-0 Hydraulics of Fire Protection Systems
 NFPA 13 - Standard for the Installation of Sprinkler Systems.
 NFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances
 Local Fire Department and Fire Marshall Regulations including hose unit threading requirements.

 UL and FM Compliance:  Fire protection system materials and components shall be Underwriter's Laboratories
 listed and labeled, and Factory Mutual approved for the application anticipated.

 Field Acceptance Test Report

 Authorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities:

 State Fire Marshall
 Local Fire Department
 Local Building Code Department
 Factory Mutual
 Owner’s Insuring Agency

 1.4.
 EXTRA MATERIALS

 Valve Wrenches:  Furnish to Owner, two (2) valve wrenches for each type of sprinkler head installed.

 Sprinkler Heads and Cabinets:  Furnish six (6) extra sprinkler heads of each style included in the project.  Furnish
 each style with its own sprinkler head cabinet and special wrenches.


 PAGE : 2


 PART 2. - PRODUCTS

 2.1.
 ACCEPTABLE MANUFACTURERS

 Manufacturers:  Except where manufacturers are specifically indicated herein, they are subject to compliance
 with the requirements of these specifications, products and manufacturers which are listed in Underwriters'
 Laboratories Publications and Factory Mutual's Approval Guide as acceptable.

 2.2.
 INSIDE ABOVE GROUND PIPE

 Steel Pipe:  ASTM A53/A53 M-01 or A135-01, Schedule 40, seamless or ERW, black steel pipe, plain ends for
 2" and below.

 Steel Pipe:  ASTM A53/A53M-01 or A135-01, Schedule 10 [confirm with owner], seamless or ERW, black steel
 pipe, plain ends for above 2½".

 Piping with wall thickness below schedule 10 shall not be used.  This includes “Dynaflow” piping.

 Clean Manufacturing or Support Areas:  Exposed sprinkler piping in these areas shall be schedule 40, 304L
 stainless steel with threaded or welded connections. No exposed sprinkler piping over 2” will be allowed in these
 areas.  Refer to HVAC clean classification plans for extent of clean areas.

 2.3.
 FITTINGS

 Cast-Iron Threaded Fittings:  ASME B16.4-1998, Class 125 for system pressure up to 175 psi, standard pattern,
 for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001).

 Malleable-Iron Threaded Fittings:  ASME B16.3-1998, Class 150 for system pressure up to 175 psi, standard
 pattern, for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001)

 Grooved Mechanical Fittings:  ASTM A 536 Amendment 1-00, Grade 65-45-12 ductile iron; ASTM A 47/A47M-
 93 (2002) Grade 32510 malleable iron; or ASTM A53/A53M-01, Type F or Types E or S, Grade B fabricated
 steel fittings with grooves or shoulders designed to accept grooved end couplings.

 Stainless Steel Threaded Fittings:  ASTM A351, Class 150 for system pressure up to 175 psi stainless steel
 threaded fittings. Threads shall conform to ASME B1.20.1-1983 (R2001)

 Cast Iron Flanged Fittings: ASME/ANSI B16.1-1998, Class 125 for system pressure up to 175 psi.

 Ductile Iron or Steel Flanged Fittings:  ASME/ANSI B16.5-1996, Class 150 for system pressure up to 175 psi.

 Grooved Mechanical Couplings:  Consist of ductile or malleable iron housing, a synthetic rubber gasket of a
 central cavity pressure-responsive design, with nuts, bolts, locking pin, locking toggle, or lugs to secure roll-
 grooved pipe and fittings.

 2.4.
 JOINING MATERIALS

 Gasket Materials:  Thickness, material, and type suitable for fluid or gas to be handled, including design
 temperatures and pressures.




 PAGE : 3


 2.5.
 VALVES

 Gate Valves (Above Ground):  Provide gate valves, UL listed, 175 psi working pressure.  Provide threaded,
 flanged, hub, or other end configurations to suit size of valve and piping connection.  Valves shall have solid
 wedge, outside screw and yoke, rising stem.  Valves shall be capable of being repacked under pressure, with valve
 wide open.

 Acceptable Manufacturers

 Crane Valve
 Nibco Valve
 Kennedy Valve

 Check Valves:  Provide check valves as indicated, UL listed, 175 psi working pressure.  Provide swing or wafer
 type, iron body, bronze or stainless steel mounted with metal-to-metal or rubber-faced checks.  Provide threaded,
 flanged, or hub end, to suit size and piping connections.

 Acceptable Manufacturers

 Fairbanks Co.
 Kennedy Valve; Div. of ITT Grinnell Valve Co., Inc.
 Mueller Co.
 Nibco Inc.

 Stockham Valves & Fittings Inc.

 2.6.
 AUTOMATIC SPRINKLERS

 Automatic Sprinklers:  Fusible link or glass bulb type and style as indicated or required by the application.  Unless
 otherwise indicated, provide sprinklers with nominal 1/2" discharge orifice and ordinary temperature range. All
 sprinkler heads shall be UL listed and FM approved.

 Acceptable Manufacturers

 Viking
 Reliable
 Central/Tyco
 Automatic Sprinkler Co.


 Sprinkler heads in cold rooms under shall be dry pendant type unless noted otherwise on drawings.
 Sprinkler heads in warehouse high bays where the roof/ceiling does not exceed 40’ shall be ESFR type unless
 noted otherwise on drawings.

 Sprinkler Finishes:  Provide sprinklers with the following finishes:

 Finished Spaces:  Sidewall or Pendant sprinkler heads shall be selected to blend in with the ceiling system and
 color.  Coordinate sprinkler head colors with architect.  Unless otherwise noted sprinklers in office or lab areas
 shall be semi-recessed type.

 Unfinished Spaces or Not Exposed to View:  Sidewall or Upright brass finished sprinkler.

 Clean Room:  Clean room sprinkler shall be concealed type sprinklers unless noted otherwise on drawings.

 Provide stainless steel sprinkler head cages for sprinkler heads under platforms or within 7’-0” of floors or
 walkable ceilings.
 PAGE : 4


 2.7.
 ALARM DEVICES

 General:  Types and sizes shall mate and match piping and equipment connections.  Alarm devices shall activate
 upon the opening of one sprinkler head.

 Waterflow Switches:  Vane type waterflow detectors shall be installed on the sprinkler system piping as
 designated on the drawings and/or as specified herein.  Detectors shall be designed for mounting on either vertical
 or horizontal piping but shall not be mounted in a fitting or within 12” of any fitting that changes the direction of
 waterflow, and shall have a sensitivity setting to signal any flow of water that equals or exceeds the discharge
 from one sprinkler head.  Detector switch mechanisms shall incorporate an instantly recycling retard element in
 the adjustable range of 0 to 70 seconds.  Switches shall have a minimum rated capacity of seven (7) amp 125V
 AC - .25 amp 24V DC and two (2) normally open contacts and shall be actuated by a polyethylene vane extending
 into the waterway of the piping.  Detectors shall be weatherproof, dust tight construction and shall provide a ½”
 conduit entrance and shall be finished in red baked enamel.  Vane waterflow detectors shall be UL listed and FM
 approved.

 Supervisory Devices:  Supervisory switches shall be installed on each control valve in sprinkler system.

 Switches shall be mounted so not to interfere with the normal operation of the valve and shall be adjusted to
 operate within two (2) revolutions of the valve control or when the stem has moved no more than 1/5 of the
 distance from its normal position.  The mechanism shall be contained in a weatherproof die cast aluminum
 housing, which shall provide a 2/4” tapped conduit entrance and incorporate the necessary facilities for minimum
 rated capacity of 1 amp.  125V AC - 0.25 amp, 24V DC.  The entire installed assembly shall be tamperproof and
 arranged to cause a switch operation if the housing cover is removed or if the unit is removed from its mounting.
 Gate valve switches shall be UL listed and FM approved.

 2.8.
 HANGERS AND SUPPORTS

 Except as otherwise indicated, provide factory-fabricated piping hangers, supports, riser clamps, rod attachments,
 building attachments, shields and saddles, of the following MSS types listed, to suit piping systems.

 Select and apply UL listed and FM approved supports. Select size of hangers and supports to fit pipe size for bare
 piping.

 Horizontal-Piping Hangers shall be:

 Adjustable steel clevis hangers, MSS-SP-69 Type 1; or
 Adjustable steel band hangers, MSS- SP-69 Type 7; or
 Adjustable swivel rings, band type, MSS- SP-69 Type 10

 Vertical-Piping Clamps shall be two-bolt riser clamps, MSS Type 8.

 Exposed sprinkler piping in classified process clean rooms shall be Universal Suspension Systems (Sanitech or
 Behringer), modular clamping system, or equivalent by Swagelok.  Finish shall be blue or other Owner approved
 color.

 2.9.
 ACCESSORIES

 Clamps, Straps, and Washers:
 Steel, ASTM A 506-04.
 Rods:
 Steel, ASTM A 575-96.
 Rod Couplings:
 Malleable-iron, ASTM A 197/A19TM-00.
 Bolts:
 Steel, ASTM A 307-04.
 Cast-Iron Washers:
 Gray-iron, ASTM A 126-04.
 PAGE : 5


 Escutcheons:
 Shall be chrome plates steel in non-process areas and
 polished stainless steel in process areas.

 2.10. INSPECTOR’S TEST CONNECTION

 Provide inspector’s test connections as specified in NFPA 13, at required points for testing each water-flow alarm
 device.  Special discharge nozzle shall have same size orifice as majority of sprinkler heads installed.


 PART 3. - EXECUTION

 3.1.
 INSTALLATION OF PIPE AND FITTINGS - INTERIOR

 Install Schedule 40 steel pipe with cut or rolled grooved ends and grooved mechanical couplings.  Piping under
 2" may utilize threaded connections.

 Install Schedule 10 steel pipe with roll-grooved ends and grooved mechanical couplings for pipe sizes 2” and
 above.

 Exposed sprinkler piping in process areas shall have threaded or welded connections.  Exposed threads shall be
 limited to one thread.

 3.2.
 PIPING INSTALLATIONS

 Locations and Arrangements:  In general run piping:
 •
 Install sprinkler piping to provide for system drainage in accordance with NFPA 13.
 •
 Provide 2” main drain valves at system valves and route 2” drains to approved drain locations.
 •
 Install mechanical sleeve seal at piping penetrations in outside walls and structural walls.
 •
 Use approved fittings to make all changes in direction, branch takeoffs from mains, and reductions
 in pipe sizes.
 •
 Install unions in pipes 2" and smaller, adjacent to each valve.  Unions are not required on flanged
 devices or in piping installations using grooved mechanical couplings.
 •
 Coordinate sprinkler pipe routing, sprinkler heads and smoke detector locations with all other trades,
 including HVAC ductwork, lighting, process and plumbing piping, etc.  Where a conflict exists
 between sprinkler piping and ductwork, process and/or plumbing piping, the sprinkler piping shall
 be offset to avoid the conflict.
 •
 Sprinkler heads shall be installed in the center of a ceiling tile whenever possible.  In general
 sprinkler heads shall be installed to provide a uniform ceiling appearance whenever possible.

 Hangers and Supports:  Comply with the latest requirements of NFPA 13 and NFPA 14.  Hanger and support
 spacing and locations for piping joined with grooved mechanical couplings shall be in accordance with the
 grooved mechanical coupling manufacturer's written instructions, for rigid systems.  Provide protection from
 damage where subject to earthquake in accordance with NFPA 13.

 Hangers and Supports for Clean Manufacturing or Support Areas:  Hangers and supports for exposed sprinkler
 piping in these areas shall meet FDA sanitary requirements for cleanability.

 Make connections between underground and above-ground piping using an approved transition piece strapped or
 fastened to prevent separation.

 Install test connections sized and located in accordance with NFPA 13 complete with shutoff valve.  Test
 connections may also serve as drain pipes.

 PAGE : 6


 Install pressure gauge on the riser or feed main at or near each test connection.  Provide gauge with a connection
 not less than 1/4" and having a soft metal seated globe valve, arranged for draining pipe between gauge and valve.
 Install gauges to permit removal, and where they will not be subject to freezing.

 Install wall or ceiling escutcheons where exposed sprinkler piping passes through ceilings or walls.

 3.3.
 PIPE JOINT CONSTRUCTION

 Welded Joints:  AWS D10.9, Level AR-3.

 Threaded Joints:  Conform to ANSI B1.20.1-1983 (R2001), tapered pipe threads for field cut threads.  Join pipe,
 fittings, and valves as follows:
 •
 Note the internal length of threads in fittings or valve ends, and proximity of internal seat or wall,
 to determine how far pipe should be threaded into joint.
 •
 Align threads at point of assembly.
 •
 Apply appropriate tape or thread compound to the external pipe threads.
 •
 Assemble joint to appropriate thread depth.  When using a wrench on valves place the wrench on
 the valve end into which the pipe is being threaded.

 Damaged Threads:  Do not use pipe with threads that are corroded or damaged.  If a weld opens during cutting
 or threading operations, that portion of pipe shall not be used.

 Flanged Joints:  Align flanges surfaces parallel.  Assemble joints by sequencing bolt tightening to make initial
 contact of flanges and gaskets as flat and parallel as possible.  Use suitable lubricants on bolt threads.  Tighten
 bolts gradually and uniformly to appropriate torque specified by the bolt manufacturer.

 Mechanical Grooved Joints:  Cut or roll grooves on pipe ends dimensionally compatible with the couplings.

 End Treatment:  After cutting pipe lengths, remove burrs and fins from pipe ends.

 Plain end fittings shall not be used.

 3.4.
 VALVE INSTALLATIONS

 General:  Install fire protection specialty valves, fittings, and specialties in accordance with the manufacturer's
 written instructions, NFPA 13and the authority having jurisdiction.

 Valves:  Install supervised-open gate or butterfly valves so located to control all sources of water supply except
 fire department connections.  Where there is more than one control valve, provide permanently marked
 identification signs indicating the portion of the system controlled by each valve.

 Install flow switches in each zone as indicated on the drawings.

 Install check valves in each water supply connection.

 Alarm Check Valves:  Install valves in the vertical position, in proper direction of flow including the bypass check
 valve and retard chamber drain line connection.  Install valve trim in accordance with the valve manufacturer's
 appropriate trim diagram.  Test valve for proper operation.

 3.5.
 SPRINKLER HEAD INSTALLATIONS

 Provide clean room style sprinkler heads in clean rooms, rooms with hard gypsum ceilings, cold rooms, and
 elsewhere as indicated. Do not seal clean room cover, seal sprinkler enclosure above ceiling.

 PAGE : 7


 Use proper tools to prevent damage during installations.

 Install per installation requirements indicated by NFPA 13.

 3.6.
 FIELD QUALITY CONTROL

 Flush, test, and inspect sprinkler piping systems in accordance with NFPA 13.

 Piping Tests:  Conduct piping tests before joints are covered, and after thrust blocks have sufficiently hardened
 for underground piping.  Fill pipeline with water 24 hours prior to testing and apply test pressure to stabilize
 system.

 Hydrostatic Tests:  Test at not less than 200 psi for two (2) hours or at 50 psi above maximum static pressure if it
 is greater than 150 psi.

 Increase pressure in 50 psi increments and inspect each joint between increments.  Hold at test pressure for one
 (1) hour, decrease to zero (0) psi.  Slowly increase again to test pressure and hold for one (1) more hour.

 Operating Tests:  Open and close all valves under system water pressure.

 Replace piping system components, which do not pass the test procedures specified, and retest repaired portion
 of the system.

 3.7.
 ADJUSTING AND CLEANING

 Flushing:  Flush underground mains, lead-in connections to sprinkler risers, and system piping before connection
 is made to sprinklers, or other fire protection system piping.

 Flush at flow rate not less than that indicated in NFPA 24, or at hydraulically calculated water demand rate of the
 system, whichever is greater.

 3.8.
 IDENTIFICATION SIGNS

 Provide all necessary identification signs for piping, control valves, main drain valves, auxiliary drains, test drains
 and all other signs which may be required by NFPA or FM requirements. Refer to Specification 200553 Tagging
 and Identification for pipe labeling requirements.


 END OF SECTION
"""

# %% [markdown]
# ## Step 3 - Preprocessing Data

# %% [markdown]
# ### A. Use Custom NER To Extract Section Number, Section Name

# %%
# pre_data = """
# SECTION 011000
#                                                                                                         SUMMARY OF WORK 

#  PART 1. - GENERAL

#  PART 1. - GENERAL

#  1.1
#  RELATED DOCUMENTS

#  A. Drawings and general provisions of the Contract, including General and Supplementary Condi-
#  tions, and other Division 01 Specification Sections, apply to this Section.""".strip()

# %%
pre_data1 = ""
for line in pre_data.splitlines():
    pre_data1 = pre_data1 + line.strip() + " \n"
    # print(line)

# print(pre_data1)

# %%
start_index = re.search(r'SECTION|DOCUMENT', pre_data1).start()
end_index= pre_data1.rindex("PART 1")
first_part_index = pre_data1.index("PART 1")

# print(end_index)
section_details = pre_data1[start_index:first_part_index]
section_details
# Out:
# 'SECTION 210900 \nWET FIRE PROTECTION SYSTEMS \n \n \nINDEX \nPAGE \n \n'

# %%
section_details = section_details.replace("\n", "")
section_details
# Out:
# 'SECTION 210900 WET FIRE PROTECTION SYSTEMS   INDEX PAGE  '

# %%
nlp2 = spacy.load("Spacy Custom NER Dump/")

spec_number = ""
spec_name = ""
flag1, flag2 = False, False
section_data = nlp2(section_details)
for sent in section_data.ents:
    print(sent)
    if(sent.label_ == 'section_number'):
        spec_number = str(sent)
        flag1 = True
    elif(sent.label_ == 'section_name'):
        spec_name = str(sent)
        flag2 = True
    elif(flag1 and flag2):
        break

if(not flag1):
    spec_number = "NA"

if(not flag2):
    spec_name = "NA"

if(not flag1 and not flag2):
    sect

print("Section Number - {}".format(spec_number))
print("Section Name - {}".format(spec_name))
# Out:
# 210900
# INDEX PAGE
# Section Number - 210900
# Section Name - INDEX PAGE

# %%
section_details1 = []
for line in section_details.splitlines():
    if(line.strip() == ""):
        continue
    else:
        section_details1.append(line.strip())

# %% [markdown]
# ### B. Removed Empty Lines and End Of Section/ Document

# %%
# pre_data1[start_index:first_part_index]
data = pre_data1[end_index:]
data
# Out:
# 'PART 1. - GENERAL \n \nThis specification for the fire protection work is intended to be a performance type specification for the design, \nfurnishing and complete installation of an automatic fire protection sprinkler system for complete coverage of all \nrenovated and new spaces within the contract limits and to conform to the requirements of NFPA 13, this \nspecification, owner’s insurance underwriter, AXA XL, and to the requirements of State and Local Codes and \nRegulations. \n \n1.1. \nSYSTEM DESCRIPTION \n \nFire Protection System shall be a “Wet-Pipe” system employing automatic sprinklers attached to a piping system \ncontaining water and connected to a water supply so that water discharges immediately from the sprinkler head \nopened by fire.  Fire Protection System shall be approved by AXA XL formerly XLGAPS and the local Authority \nHaving Jurisdiction. \n \n1.2. \nSUBMITTALS \n \nProduct Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department \nconnections specified and/or provided. \n \nPAGE : 1 \n \n \nShop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,” \nand consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction. \nSubmit shop drawings showing piping materials, size, locations, and elevations. Include details of underground \nstructures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and \nproximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic \ncalculations. \n \nHydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been \napproved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information, \nsprinkler system requirements, water supply information including water supply and sprinkler system demand \ncurves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference \npoints corresponding to reference points indicated on shop drawings. \n \nMaintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department \nconnection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual. \n \nTest Reports and Certificates including “Contractor\'s Material & Test Certificate for Aboveground Piping” and \n“Contractor\'s Material & Test Certificate for Underground Piping” as described in NFPA 13. \n \n1.3. \nQUALITY ASSURANCE \n \nRegulatory Requirements:  Comply with the requirements of the following codes: \n \nFM DS 2-0 Installation Guidelines for Automatic Sprinklers \nFM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems \nFM DS 3-0 Hydraulics of Fire Protection Systems \nNFPA 13 - Standard for the Installation of Sprinkler Systems. \nNFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances \nLocal Fire Department and Fire Marshall Regulations including hose unit threading requirements. \n \nUL and FM Compliance:  Fire protection system materials and components shall be Underwriter\'s Laboratories \nlisted and labeled, and Factory Mutual approved for the application anticipated. \n \nField Acceptance Test Report \n \nAuthorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities: \n \nState Fire Marshall \nLocal Fire Department \nLocal Building Code Department \nFactory Mutual \nOwner’s Insuring Agency \n \n1.4. \nEXTRA MATERIALS \n \nValve Wrenches:  Furnish to Owner, two (2) valve wrenches for each type of sprinkler head installed. \n \nSprinkler Heads and Cabinets:  Furnish six (6) extra sprinkler heads of each style included in the project.  Furnish \neach style with its own sprinkler head cabinet and special wrenches. \n \n \nPAGE : 2 \n \n \nPART 2. - PRODUCTS \ ...

# %%
section_details1
# Out:
# ['SECTION 210900 WET FIRE PROTECTION SYSTEMS   INDEX PAGE']

# %%
final_data = ""
head_flag = True
for index, line in enumerate(data.splitlines()):
    if("END OF SECTION" in line or "END OF DOCUMENT" in line.strip()):
        continue
    elif(len(line.strip()) == 0):
        continue
    elif([ele for ele in section_details1 if(ele in line.strip())]):
        # print(line)
        continue
    else:
        final_data = final_data + line.strip() + "\n"
    
    
print(final_data)
# Out:
# PART 1. - GENERAL
# This specification for the fire protection work is intended to be a performance type specification for the design,
# furnishing and complete installation of an automatic fire protection sprinkler system for complete coverage of all
# renovated and new spaces within the contract limits and to conform to the requirements of NFPA 13, this
# specification, owner’s insurance underwriter, AXA XL, and to the requirements of State and Local Codes and
# Regulations.
# 1.1.
# SYSTEM DESCRIPTION
# Fire Protection System shall be a “Wet-Pipe” system employing automatic sprinklers attached to a piping system
# containing water and connected to a water supply so that water discharges immediately from the sprinkler head
# opened by fire.  Fire Protection System shall be approved by AXA XL formerly XLGAPS and the local Authority
# Having Jurisdiction.
# 1.2.
# SUBMITTALS
# Product Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department
# connections specified and/or provided.
# PAGE : 1
# Shop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,”
# and consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction.
# Submit shop drawings showing piping materials, size, locations, and elevations. Include details of underground
# structures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and
# proximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic
# calculations.
# Hydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been
# approved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information,
# sprinkler system requirements, water supply information including water supply and sprinkler system demand
# curves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference
# points corresponding to reference points indicated on shop drawings.
# Maintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department
# connection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual.
# Test Reports and Certificates including “Contractor's Material & Test Certificate for Aboveground Piping” and
# “Contractor's Material & Test Certificate for Underground Piping” as described in NFPA 13.
# 1.3.
# QUALITY ASSURANCE
# Regulatory Requirements:  Comply with the requirements of the following codes:
# FM DS 2-0 Installation Guidelines for Automatic Sprinklers
# FM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems
# FM DS 3-0 Hydraulics of Fire Protection Systems
# NFPA 13 - Standard for the Installation of Sprinkler Systems.
# NFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances
# Local Fire Department and Fire Marshall Regulations including hose unit threading requirements.
# UL and FM Compliance:  Fire protection system materials and components shall be Underwriter's Laboratories
# listed and labeled, and Factory Mutual approved for the application anticipated.
# Field Acceptance Test Report
# Authorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities:
# State Fire Marshall
# Local Fire Department
# Local Building Code Department
# Factory Mutual
# Owner’s Insuring Agency
# 1.4.
# EXTRA MATERIALS
# Valve Wrenches:  Furnish to Owner, two (2) valve wrenches for each type of sprinkler head installed.
# Sprinkler Heads and Cabinets:  Furnish six (6) extra sprinkler heads of each style included in the project.  Furnish
# each style with its own sprinkler head cabinet and special wrenches.
# PAGE : 2
# PART 2. - PRODUCTS
# 2.1.
# ACCEPTABLE MANUFACTURERS
# Manufacturers:  Except where manufacturers are specifically indicated herein, they are subject to compliance
# with the requirements of these specifications, products and manufacturers which are listed in Underwriters'
# Laboratories Publications and Factory Mutual's Approval Guide as acceptable.
# 2.2.
# INSIDE ABOVE GROUND PIPE
# Steel Pipe:  ASTM A53/A53 M-01 or A135-01, Schedule 40, seamless or ERW, black steel pipe, plain ends for
# 2" and below.
# Steel Pipe:  ASTM A53/A53M-01 or A135-01, Schedule 10 [confirm with owner], seamless or ERW, black steel
# pipe, plain ends for above 2½".
# Piping with wall thickness below schedule 10 shall not be used.  This includes “Dynaflow” piping.
# Clean Manufacturing or Support Areas:  Exposed sprinkler piping in these areas shall be schedule 40, 304L
# stainless steel with threaded or welded connections. No exposed sprinkler piping over 2” will be allowed in these
# areas.  Refer to HVAC clean classification plans for extent of clean areas.
# 2.3.
# FITTINGS
# Cast-Iron Threaded Fittings:  ASME B16.4-1998, Class 125 for system pressure up to 175 psi, standard pattern,
# for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001).
# Malleable-Iron Threaded Fittings:  ASME B16.3-1998, Class 150 for system pressure up to 175 psi, standard
# pattern, for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001)
# Grooved Mechanical Fittings:  ASTM A 536 Amendment 1-00, Grade 65-45-12 ductile iron; ASTM A 47/A47M-
# 93 (2002) Grade 32510 malleable iron; or ASTM A53/A53M-01, Type F or Types E or S, Grade B fabricated
# steel fittings with grooves or shoulders designed to accept grooved end couplings.
# Stainless Steel Threaded Fittings:  ASTM A351, Class 150 for system pressure up to 175 psi stainless steel
# threaded fittings. Threads shall conform to ASME B1.20.1-1983 (R2001)
# Cast Iron Flanged Fittings: ASME/ANSI B16.1-1998, Class 125 for system pressure up to 175 psi.
# Ductile Iron or Steel Flanged Fittings:  ASME/ANSI B16.5-1996, Class 150 for system pressure up to 175 psi.
# Grooved Mechanical Couplings:  Consist of ductile or malleable iron housing, a synthetic rubber gasket of a
# central cavity pressure-responsive design, with nuts, bolts, locking pin, locking toggle, or lugs to secure roll-
# grooved pipe and fittings.
# 2.4.
# JOINING MATERIALS
# Gasket Materials:  Thickness, material, and type suitable for fluid or gas to be handled, including design
# temperatures and pressures.
# PAGE : 3
# 2.5.
# VALVES
# Gate Valves (Above Ground):  Provide gate valves, UL listed, 175 psi working pressure.  Provide threaded,
# flanged, hub, or other end configurations to suit size of valve and piping connection.  Valves shall have solid
# wedge, outside screw and yoke, rising stem.  Valves shall be capable of being repacked under pressure, with valve
# wide open.
# Acceptable Manufacturers
# Crane Valve
# Nibco Valve
# Kennedy Valve
# Check Valves:  Provide check valves as indicated, UL listed, 175 psi working pressure.  Provide swing or wafer
# type, iron body, bronze or stainless steel mounted with metal-to-metal or rubber-faced checks.  Provide threaded,
# flanged, or hub end, to suit size and piping connections.
# Acceptable Manufacturers
# Fairbanks Co.
# Kennedy Valve; Div. of ITT Grinnell Valve Co., Inc.
# Mueller Co.
# Nibco Inc.
# Stockham Valves & Fittings Inc.
# 2.6.
# AUTOMATIC SPRINKLERS
# Automatic Sprinklers:  Fusible link or glass bulb type and style as indicated or required by the application.  Unless
# otherwise indicated, provide sprinklers with nominal 1/2" discharge orifice and ordinary temperature range. All
# sprinkler heads shall be UL listed and FM approved.
# Acceptable Manufacturers
# Viking
# Reliable
# Central/Tyco
# Automatic Sprinkler Co.
# Sprinkler heads in cold rooms under shall be dry pendant type unless noted otherwise on drawings.
# Sprinkler heads in warehouse high bays where the roof/ceiling does not exceed 40’ shall be ESFR type unless
# noted otherwise on drawings.
# Sprinkler Finishes:  Provide sprinklers with the following finishes:
# Finished Spaces:  Sidewall or Pendant sprinkler heads shall be selected to blend in with the ceiling system and
# color.  Coordinate sprinkler head colors with architect.  Unless otherwise noted sprinklers in office or lab areas
# shall be semi-recessed type.
# Unfinished Spaces or Not Exposed to View:  Sidewall or Upright brass finished sprinkler.
# Clean Room:  Clean room sprinkler shall be concealed type sprinklers unless noted otherwise on drawings.
# Provide stainless steel sprinkler head cages for sprinkler heads under platforms or within 7’-0” of floors or
# walkable ceilings.
# PAGE : 4
# 2.7.
# ALARM DEVICES
# General:  Types and sizes shall mate and match piping and equipment connections.  Alarm devices shall activate
# upon the opening of one sprinkler head.
# Waterflow Switches:  Vane type waterflow detectors shall be installed on the sprinkler system piping as
# designated on the drawings and/or as specified herein.  Detectors shall be designed for mounting on either vertical
# or horizontal piping but shall not be mounted in a fitting or within 12” of any fitting that changes the direction of
# waterflow, and shall have a sensitivity setting to signal any flow of water that equals or exceeds the discharge
# from one sprinkler head.  Detector switch mechanisms shall incorporate an instantly recycling retard element in
# the adjustable range of 0 to 70 seconds.  Switches shall have a minimum rated capacity of seven (7) amp 125V
# AC - .25 amp 24V DC and two (2) normally open contacts and shall be actuated by a polyethylene vane extending
# into the waterway of the piping.  Detectors shall be weatherproof, dust tight construction and shall provide a ½”
# conduit entrance and shall be finished in red baked enamel.  Vane waterflow detectors shall be UL listed and FM
# approved.
# Supervisory Devices:  Supervisory switches shall be installed on each control valve in sprinkler system.
# Switches shall be mounted so not to interfere with the normal operation of the valve and shall be adjusted to
# operate within two (2) revolutions of the valve control or when the stem has moved no more than 1/5 of the
# distance from its normal position.  The mechanism shall be contained in a weatherproof die cast aluminum
# housing, which shall provide a 2/4” tapped conduit entrance and incorporate the necessary facilities for minimum
# rated capacity of 1 amp.  125V AC - 0.25 amp, 24V DC.  The entire installed assembly shall be tamperproof and
# arranged to cause a switch operation if the housing cover is removed or if the unit is removed from its mounting.
# Gate valve switches shall be UL listed and FM approved.
# 2.8.
# HANGERS AND SUPPORTS
# Except as otherwise indicated, provide factory-fabricated piping hangers, supports, riser clamps, rod attachments,
# building attachments, shields and saddles, of the following MSS types listed, to suit piping systems.
# Select and apply UL listed and FM approved supports. Select size of hangers and supports to fit pipe size for bare
# piping.
# Horizontal-Piping Hangers shall be:
# Adjustable steel clevis hangers, MSS-SP-69 Type 1; or
# Adjustable steel band hangers, MSS- SP-69 Type 7; or
# Adjustable swivel rings, band type, MSS- SP-69 Type 10
# Vertical-Piping Clamps shall be two-bolt riser clamps, MSS Type 8.
# Exposed sprinkler piping in classified process clean rooms shall be Universal Suspension Systems (Sanitech or
# Behringer), modular clamping system, or equivalent by Swagelok.  Finish shall be blue or other Owner approved
# color.
# 2.9.
# ACCESSORIES
# Clamps, Straps, and Washers:
# Steel, ASTM A 506-04.
# Rods:
# Steel, ASTM A 575-96.
# Rod Couplings:
# Malleable-iron, ASTM A 197/A19TM-00.
# Bolts:
# Steel, ASTM A 307-04.
# Cast-Iron Washers:
# Gray-iron, ASTM A 126-04.
# PAGE : 5
# Escutcheons:
# Shall be chrome plates steel in non-process areas and
# polished stainless steel in process areas.
# 2.10. INSPECTOR’S TEST CONNECTION
# Provide inspector’s test connections as specified in NFPA 13, at required points for testing each water-flow alarm
# device.  Special discharge nozzle shall have same size orifice as majority of sprinkler heads installed.
# PART 3. - EXECUTION
# 3.1.
# INSTALLATION OF PIPE AND FITTINGS - INTERIOR
# Install Schedule 40 steel pipe with cut or rolled grooved ends and grooved mechanical couplings.  Piping under
# 2" may utilize threaded connections.
# Install Schedule 10 steel pipe with roll-grooved ends and grooved mechanical couplings for pipe sizes 2” and
# above.
# Exposed sprinkler piping in process areas shall have threaded or welded connections.  Exposed threads shall be
# limited to one thread.
# 3.2.
# PIPING INSTALLATIONS
# Locations and Arrangements:  In general run piping:
# •
# Install sprinkler piping to provide for system drainage in accordance with NFPA 13.
# •
# Provide 2” main drain valves at system valves and route 2” drains to approved drain locations.
# •
# Install mechanical sleeve seal at piping penetrations in outside walls and structural walls.
# •
# Use approved fittings to make all changes in direction, branch takeoffs from mains, and reductions
# in pipe sizes.
# •
# Install unions in pipes 2" and smaller, adjacent to each valve.  Unions are not required on flanged
# devices or in piping installations using grooved mechanical couplings.
# •
# Coordinate sprinkler pipe routing, sprinkler heads and smoke detector locations with all other trades,
# including HVAC ductwork, lighting, process and plumbing piping, etc.  Where a conflict exists
# between sprinkler piping and ductwork, process and/or plumbing piping, the sprinkler piping shall
# be offset to avoid the conflict.
# •
# Sprinkler heads shall be installed in the center of a ceiling tile whenever possible.  In general
# sprinkler heads shall be installed to provide a uniform ceiling appearance whenever possible.
# Hangers and Supports:  Comply with the latest requirements of NFPA 13 and NFPA 14.  Hanger and support
# spacing and locations for piping joined with grooved mechanical couplings shall be in accordance with the
# grooved mechanical coupling manufacturer's written instructions, for rigid systems.  Provide protection from
# damage where subject to earthquake in accordance with NFPA 13.
# Hangers and Supports for Clean Manufacturing or Support Areas:  Hangers and supports for exposed sprinkler
# piping in these areas shall meet FDA sanitary requirements for cleanability.
# Make connections between underground and above-ground piping using an approved transition piece strapped or
# fastened to prevent separation.
# Install test connections sized and located in accordance with NFPA 13 complete with shutoff valve.  Test
# connections may also serve as drain pipes.
# PAGE : 6
# Install pressure gauge on the riser or feed main at or near each test connection.  Provide gauge with a connection
# not less than 1/4" and having a soft metal seated globe valve, arranged for draining pipe between gauge and valve.
# Install gauges to permit removal, and where they will not be subject to freezing.
# Install wall or ceiling escutcheons where exposed sprinkler piping passes through ceilings or walls.
# 3.3.
# PIPE JOINT CONSTRUCTION
# Welded Joints:  AWS D10.9, Level AR-3.
# Threaded Joints:  Conform to ANSI B1.20.1-1983 (R2001), tapered pipe threads for field cut threads.  Join pipe,
# fittings, and valves as follows:
# •
# Note the internal length of threads in fittings or valve ends, and proximity of internal seat or wall,
# to determine how far pipe should be threaded into joint.
# •
# Align threads at point of assembly.
# •
# Apply appropriate tape or thread compound to the external pipe threads.
# •
# Assemble joint to appropriate thread depth.  When using a wrench on valves place the wrench on
# the valve end into which the pipe is being threaded.
# Damaged Threads:  Do not use pipe with threads that are corroded or damaged.  If a weld opens during cutting
# or threading operations, that portion of pipe shall not be used.
# Flanged Joints:  Align flanges surfaces parallel.  Assemble joints by sequencing bolt tightening to make initial
# contact of flanges and gaskets as flat and parallel as possible.  Use suitable lubricants on bolt threads.  Tighten
# bolts gradually and uniformly to appropriate torque specified by the bolt manufacturer.
# Mechanical Grooved Joints:  Cut or roll grooves on pipe ends dimensionally compatible with the couplings.
# End Treatment:  After cutting pipe lengths, remove burrs and fins from pipe ends.
# Plain end fittings shall not be used.
# 3.4.
# VALVE INSTALLATIONS
# General:  Install fire protection specialty valves, fittings, and specialties in accordance with the manufacturer's
# written instructions, NFPA 13and the authority having jurisdiction.
# Valves:  Install supervised-open gate or butterfly valves so located to control all sources of water supply except
# fire department connections.  Where there is more than one control valve, provide permanently marked
# identification signs indicating the portion of the system controlled by each valve.
# Install flow switches in each zone as indicated on the drawings.
# Install check valves in each water supply connection.
# Alarm Check Valves:  Install valves in the vertical position, in proper direction of flow including the bypass check
# valve and retard chamber drain line connection.  Install valve trim in accordance with the valve manufacturer's
# appropriate trim diagram.  Test valve for proper operation.
# 3.5.
# SPRINKLER HEAD INSTALLATIONS
# Provide clean room style sprinkler heads in clean rooms, rooms with hard gypsum ceilings, cold rooms, and
# elsewhere as indicated. Do not seal clean room cover, seal sprinkler enclosure above ceiling.
# PAGE : 7
# Use proper tools to prevent damage during installations.
# Install per installation requirements indicated by NFPA 13.
# 3.6.
# FIELD QUALITY CONTROL
# Flush, test, and inspect sprinkler piping systems in accordance with NFPA 13.
# Piping Tests:  Conduct piping tests before joints are covered, and after thrust blocks have sufficiently hardened
# for underground piping.  Fill pipeline with water 24 hours prior to testing and apply test pressure to stabilize
# system.
# Hydrostatic Tests:  Test at not less than 200 psi for two (2) hours or at 50 psi above maximum static pressure if it
# is greater than 150 psi.
# Increase pressure in 50 psi increments and inspect each joint between increments.  Hold at test pressure for one
# (1) hour, decrease to zero (0) psi.  Slowly increase again to test pressure and hold for one (1) more hour.
# Operating Tests:  Open and close all valves under system water pressure.
# Replace piping system components, which do not pass the test procedures specified, and retest repaired portion
# of the system.
# 3.7.
# ADJUSTING AND CLEANING
# Flushing:  Flush underground mains, lead-in connections to sprinkler risers, and system piping before connection
# is made to sprinklers, or other fire protection system piping.
# Flush at flow rate not less than that indicated in NFPA 24, or at hydraulically calculated water demand rate of the
# system, whichever is greater.
# 3.8.
# IDENTIFICATION SIGNS
# Provide all necessary identification signs for piping, control valves, main drain valves, auxiliary drains, test drains
# and all other signs which may be required by NFPA or FM requirements. Refer to Specification 200553 Tagging
# and Identification for pipe labeling requirements.

# %%
for index, line in enumerate(final_data.splitlines()):
    print(index, line)
# Out:
# 0 PART 1. - GENERAL
# 1 This specification for the fire protection work is intended to be a performance type specification for the design,
# 2 furnishing and complete installation of an automatic fire protection sprinkler system for complete coverage of all
# 3 renovated and new spaces within the contract limits and to conform to the requirements of NFPA 13, this
# 4 specification, owner’s insurance underwriter, AXA XL, and to the requirements of State and Local Codes and
# 5 Regulations.
# 6 1.1.
# 7 SYSTEM DESCRIPTION
# 8 Fire Protection System shall be a “Wet-Pipe” system employing automatic sprinklers attached to a piping system
# 9 containing water and connected to a water supply so that water discharges immediately from the sprinkler head
# 10 opened by fire.  Fire Protection System shall be approved by AXA XL formerly XLGAPS and the local Authority
# 11 Having Jurisdiction.
# 12 1.2.
# 13 SUBMITTALS
# 14 Product Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department
# 15 connections specified and/or provided.
# 16 PAGE : 1
# 17 Shop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,”
# 18 and consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction.
# 19 Submit shop drawings showing piping materials, size, locations, and elevations. Include details of underground
# 20 structures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and
# 21 proximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic
# 22 calculations.
# 23 Hydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been
# 24 approved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information,
# 25 sprinkler system requirements, water supply information including water supply and sprinkler system demand
# 26 curves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference
# 27 points corresponding to reference points indicated on shop drawings.
# 28 Maintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department
# 29 connection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual.
# 30 Test Reports and Certificates including “Contractor's Material & Test Certificate for Aboveground Piping” and
# 31 “Contractor's Material & Test Certificate for Underground Piping” as described in NFPA 13.
# 32 1.3.
# 33 QUALITY ASSURANCE
# 34 Regulatory Requirements:  Comply with the requirements of the following codes:
# 35 FM DS 2-0 Installation Guidelines for Automatic Sprinklers
# 36 FM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems
# 37 FM DS 3-0 Hydraulics of Fire Protection Systems
# 38 NFPA 13 - Standard for the Installation of Sprinkler Systems.
# 39 NFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances
# 40 Local Fire Department and Fire Marshall Regulations including hose unit threading requirements.
# 41 UL and FM Compliance:  Fire protection system materials and components shall be Underwriter's Laboratories
# 42 listed and labeled, and Factory Mutual approved for the application anticipated.
# 43 Field Acceptance Test Report
# 44 Authorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities:
# 45 State Fire Marshall
# 46 Local Fire Department
# 47 Local Building Code Department
# 48 Factory Mutual
# 49 Owner’s Insuring Agency
# 50 1.4.
# 51 EXTRA MATERIALS
# 52 Valve Wrenches:  Furnish to Owner, two (2) valve wrenches for each type of sprinkler head installed.
# 53 Sprinkler Heads and Cabinets:  Furnish six (6) extra sprinkler heads of each style included in the project.  Furnish
# 54 each style with its own sprinkler head cabinet and special wrenches.
# 55 PAGE : 2
# 56 PART 2. - PRODUCTS
# 57 2.1.
# 58 ACCEPTABLE MANUFACTURERS
# 59 Manufacturers:  Except where manufacturers are specifically indicated herein, they are subject to compliance
# 60 with the requirements of these specifications, products and manufacturers which are listed in Underwriters'
# 61 Laboratories Publications and Factory Mutual's Approval Guide as acceptable.
# 62 2.2.
# 63 INSIDE ABOVE GROUND PIPE
# 64 Steel Pipe:  ASTM A53/A53 M-01 or A135-01, Schedule 40, seamless or ERW, black steel pipe, plain ends for
# 65 2" and below.
# 66 Steel Pipe:  ASTM A53/A53M-01 or A135-01, Schedule 10 [confirm with owner], seamless or ERW, black steel
# 67 pipe, plain ends for above 2½".
# 68 Piping with wall thickness below schedule 10 shall not be used.  This includes “Dynaflow” piping.
# 69 Clean Manufacturing or Support Areas:  Exposed sprinkler piping in these areas shall be schedule 40, 304L
# 70 stainless steel with threaded or welded connections. No exposed sprinkler piping over 2” will be allowed in these
# 71 areas.  Refer to HVAC clean classification plans for extent of clean areas.
# 72 2.3.
# 73 FITTINGS
# 74 Cast-Iron Threaded Fittings:  ASME B16.4-1998, Class 125 for system pressure up to 175 psi, standard pattern,
# 75 for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001).
# 76 Malleable-Iron Threaded Fittings:  ASME B16.3-1998, Class 150 for system pressure up to 175 psi, standard
# 77 pattern, for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001)
# 78 Grooved Mechanical Fittings:  ASTM A 536 Amendment 1-00, Grade 65-45-12 ductile iron; ASTM A 47/A47M-
# 79 93 (2002) Grade 32510 malleable iron; or ASTM A53/A53M-01, Type F or Types E or S, Grade B fabricated
# 80 steel fittings with grooves or shoulders designed to accept grooved end couplings.
# 81 Stainless Steel Threaded Fittings:  ASTM A351, Class 150 for system pressure up to 175 psi stainless steel
# 82 threaded fittings. Threads shall conform to ASME B1.20.1-1983 (R2001)
# 83 Cast Iron Flanged Fittings: ASME/ANSI B16.1-1998, Class 125 for system pressure up to 175 psi.
# 84 Ductile Iron or Steel Flanged Fittings:  ASME/ANSI B16.5-1996, Class 150 for system pressure up to 175 psi.
# 85 Grooved Mechanical Couplings:  Consist of ductile or malleable iron housing, a synthetic rubber gasket of a
# 86 central cavity pressure-responsive design, with nuts, bolts, locking pin, locking toggle, or lugs to secure roll-
# 87 grooved pipe and fittings.
# 88 2.4.
# 89 JOINING MATERIALS
# 90 Gasket Materials:  Thickness, material, and type suitable for fluid or gas to be handled, including design
# 91 temperatures and pressures.
# 92 PAGE : 3
# 93 2.5.
# 94 VALVES
# 95 Gate Valves (Above Ground):  Provide gate valves, UL listed, 175 psi working pressure.  Provide threaded,
# 96 flanged, hub, or other end configurations to suit size of valve and piping connection.  Valves shall have solid
# 97 wedge, outside screw and yoke, rising stem.  Valves shall be capable of being repacked under pressure, with valve
# 98 wide open.
# 99 Acceptable Manufacturers
# 100 Crane Valve
# 101 Nibco Valve
# 102 Kennedy Valve
# 103 Check Valves:  Provide check valves as indicated, UL listed, 175 psi working pressure.  Provide swing or wafer
# 104 type, iron body, bronze or stainless steel mounted with metal-to-metal or rubber-faced checks.  Provide threaded,
# 105 flanged, or hub end, to suit size and piping connections.
# 106 Acceptable Manufacturers
# 107 Fairbanks Co.
# 108 Kennedy Valve; Div. of ITT Grinnell Valve Co., Inc.
# 109 Mueller Co.
# 110 Nibco Inc.
# 111 Stockham Valves & Fittings Inc.
# 112 2.6.
# 113 AUTOMATIC SPRINKLERS
# 114 Automatic Sprinklers:  Fusible link or glass bulb type and style as indicated or required by the application.  Unless
# 115 otherwise indicated, provide sprinklers with nominal 1/2" discharge orifice and ordinary temperature range. All
# 116 sprinkler heads shall be UL listed and FM approved.
# 117 Acceptable Manufacturers
# 118 Viking
# 119 Reliable
# 120 Central/Tyco
# 121 Automatic Sprinkler Co.
# 122 Sprinkler heads in cold rooms under shall be dry pendant type unless noted otherwise on drawings.
# 123 Sprinkler heads in warehouse high bays where the roof/ceiling does not exceed 40’ shall be ESFR type unless
# 124 noted otherwise on drawings.
# 125 Sprinkler Finishes:  Provide sprinklers with the following finishes:
# 126 Finished Spaces:  Sidewall or Pendant sprinkler heads shall be selected to blend in with the ceiling system and
# 127 color.  Coordinate sprinkler head colors with architect.  Unless otherwise noted sprinklers in office or lab areas
# 128 shall be semi-recessed type.
# 129 Unfinished Spaces or Not Exposed to View:  Sidewall or Upright brass finished sprinkler.
# 130 Clean Room:  Clean room sprinkler shall be concealed type sprinklers unless noted otherwise on drawings.
# 131 Provide stainless steel sprinkler head cages for sprinkler heads under platforms or within 7’-0” of floors or
# 132 walkable ceilings.
# 133 PAGE : 4
# 134 2.7.
# 135 ALARM DEVICES
# 136 General:  Types and sizes shall mate and match piping and equipment connections.  Alarm devices shall activate
# 137 upon the opening of one sprinkler head.
# 138 Waterflow Switches:  Vane type waterflow detectors shall be installed on the sprinkler system piping as
# 139 designated on the drawings and/or as specified herein.  Detectors shall be designed for mounting on either vertical
# 140 or horizontal piping but shall not be mounted in a fitting or within 12” of any fitting that changes the direction of
# 141 waterflow, and shall have a sensitivity setting to signal any flow of water that equals or exceeds the discharge
# 142 from one sprinkler head.  Detector switch mechanisms shall incorporate an instantly recycling retard element in
# 143 the adjustable range of 0 to 70 seconds.  Switches shall have a minimum rated capacity of seven (7) amp 125V
# 144 AC - .25 amp 24V DC and two (2) normally open contacts and shall be actuated by a polyethylene vane extending
# 145 into the waterway of the piping.  Detectors shall be weatherproof, dust tight construction and shall provide a ½”
# 146 conduit entrance and shall be finished in red baked enamel.  Vane waterflow detectors shall be UL listed and FM
# 147 approved.
# 148 Supervisory Devices:  Supervisory switches shall be installed on each control valve in sprinkler system.
# 149 Switches shall be mounted so not to interfere with the normal operation of the valve and shall be adjusted to
# 150 operate within two (2) revolutions of the valve control or when the stem has moved no more than 1/5 of the
# 151 distance from its normal position.  The mechanism shall be contained in a weatherproof die cast aluminum
# 152 housing, which shall provide a 2/4” tapped conduit entrance and incorporate the necessary facilities for minimum
# 153 rated capacity of 1 amp.  125V AC - 0.25 amp, 24V DC.  The entire installed assembly shall be tamperproof and
# 154 arranged to cause a switch operation if the housing cover is removed or if the unit is removed from its mounting.
# 155 Gate valve switches shall be UL listed and FM approved.
# 156 2.8.
# 157 HANGERS AND SUPPORTS
# 158 Except as otherwise indicated, provide factory-fabricated piping hangers, supports, riser clamps, rod attachments,
# 159 building attachments, shields and saddles, of the following MSS types listed, to suit piping systems.
# 160 Select and apply UL listed and FM approved supports. Select size of hangers and supports to fit pipe size for bare
# 161 piping.
# 162 Horizontal-Piping Hangers shall be:
# 163 Adjustable steel clevis hangers, MSS-SP-69 Type 1; or
# 164 Adjustable steel band hangers, MSS- SP-69 Type 7; or
# 165 Adjustable swivel rings, band type, MSS- SP-69 Type 10
# 166 Vertical-Piping Clamps shall be two-bolt riser clamps, MSS Type 8.
# 167 Exposed sprinkler piping in classified process clean rooms shall be Universal Suspension Systems (Sanitech or
# 168 Behringer), modular clamping system, or equivalent by Swagelok.  Finish shall be blue or other Owner approved
# 169 color.
# 170 2.9.
# 171 ACCESSORIES
# 172 Clamps, Straps, and Washers:
# 173 Steel, ASTM A 506-04.
# 174 Rods:
# 175 Steel, ASTM A 575-96.
# 176 Rod Couplings:
# 177 Malleable-iron, ASTM A 197/A19TM-00.
# 178 Bolts:
# 179 Steel, ASTM A 307-04.
# 180 Cast-Iron Washers:
# 181 Gray-iron, ASTM A 126-04.
# 182 PAGE : 5
# 183 Escutcheons:
# 184 Shall be chrome plates steel in non-process areas and
# 185 polished stainless steel in process areas.
# 186 2.10. INSPECTOR’S TEST CONNECTION
# 187 Provide inspector’s test connections as specified in NFPA 13, at required points for testing each water-flow alarm
# 188 device.  Special discharge nozzle shall have same size orifice as majority of sprinkler heads installed.
# 189 PART 3. - EXECUTION
# 190 3.1.
# 191 INSTALLATION OF PIPE AND FITTINGS - INTERIOR
# 192 Install Schedule 40 steel pipe with cut or rolled grooved ends and grooved mechanical couplings.  Piping under
# 193 2" may utilize threaded connections.
# 194 Install Schedule 10 steel pipe with roll-grooved ends and grooved mechanical couplings for pipe sizes 2” and
# 195 above.
# 196 Exposed sprinkler piping in process areas shall have threaded or welded connections.  Exposed threads shall be
# 197 limited to one thread.
# 198 3.2.
# 199 PIPING INSTALLATIONS
# 200 Locations and Arrangements:  In general run piping:
# 201 •
# 202 Install sprinkler piping to provide for system drainage in accordance with NFPA 13.
# 203 •
# 204 Provide 2” main drain valves at system valves and route 2” drains to approved drain locations.
# 205 •
# 206 Install mechanical sleeve seal at piping penetrations in outside walls and structural walls.
# 207 •
# 208 Use approved fittings to make all changes in direction, branch takeoffs from mains, and reductions
# 209 in pipe sizes.
# 210 •
# 211 Install unions in pipes 2" and smaller, adjacent to each valve.  Unions are not required on flanged
# 212 devices or in piping installations using grooved mechanical couplings.
# 213 •
# 214 Coordinate sprinkler pipe routing, sprinkler heads and smoke detector locations with all other trades,
# 215 including HVAC ductwork, lighting, process and plumbing piping, etc.  Where a conflict exists
# 216 between sprinkler piping and ductwork, process and/or plumbing piping, the sprinkler piping shall
# 217 be offset to avoid the conflict.
# 218 •
# 219 Sprinkler heads shall be installed in the center of a ceiling tile whenever possible.  In general
# 220 sprinkler heads shall be installed to provide a uniform ceiling appearance whenever possible.
# 221 Hangers and Supports:  Comply with the latest requirements of NFPA 13 and NFPA 14.  Hanger and support
# 222 spacing and locations for piping joined with grooved mechanical couplings shall be in accordance with the
# 223 grooved mechanical coupling manufacturer's written instructions, for rigid systems.  Provide protection from
# 224 damage where subject to earthquake in accordance with NFPA 13.
# 225 Hangers and Supports for Clean Manufacturing or Support Areas:  Hangers and supports for exposed sprinkler
# 226 piping in these areas shall meet FDA sanitary requirements for cleanability.
# 227 Make connections between underground and above-ground piping using an approved transition piece strapped or
# 228 fastened to prevent separation.
# 229 Install test connections sized and located in accordance with NFPA 13 complete with shutoff valve.  Test
# 230 connections may also serve as drain pipes.
# 231 PAGE : 6
# 232 Install pressure gauge on the riser or feed main at or near each test connection.  Provide gauge with a connection
# 233 not less than 1/4" and having a soft metal seated globe valve, arranged for draining pipe between gauge and valve.
# 234 Install gauges to permit removal, and where they will not be subject to freezing.
# 235 Install wall or ceiling escutcheons where exposed sprinkler piping passes through ceilings or walls.
# 236 3.3.
# 237 PIPE JOINT CONSTRUCTION
# 238 Welded Joints:  AWS D10.9, Level AR-3.
# 239 Threaded Joints:  Conform to ANSI B1.20.1-1983 (R2001), tapered pipe threads for field cut threads.  Join pipe,
# 240 fittings, and valves as follows:
# 241 •
# 242 Note the internal length of threads in fittings or valve ends, and proximity of internal seat or wall,
# 243 to determine how far pipe should be threaded into joint.
# 244 •
# 245 Align threads at point of assembly.
# 246 •
# 247 Apply appropriate tape or thread compound to the external pipe threads.
# 248 •
# 249 Assemble joint to appropriate thread depth.  When using a wrench on valves place the wrench on
# 250 the valve end into which the pipe is being threaded.
# 251 Damaged Threads:  Do not use pipe with threads that are corroded or damaged.  If a weld opens during cutting
# 252 or threading operations, that portion of pipe shall not be used.
# 253 Flanged Joints:  Align flanges surfaces parallel.  Assemble joints by sequencing bolt tightening to make initial
# 254 contact of flanges and gaskets as flat and parallel as possible.  Use suitable lubricants on bolt threads.  Tighten
# 255 bolts gradually and uniformly to appropriate torque specified by the bolt manufacturer.
# 256 Mechanical Grooved Joints:  Cut or roll grooves on pipe ends dimensionally compatible with the couplings.
# 257 End Treatment:  After cutting pipe lengths, remove burrs and fins from pipe ends.
# 258 Plain end fittings shall not be used.
# 259 3.4.
# 260 VALVE INSTALLATIONS
# 261 General:  Install fire protection specialty valves, fittings, and specialties in accordance with the manufacturer's
# 262 written instructions, NFPA 13and the authority having jurisdiction.
# 263 Valves:  Install supervised-open gate or butterfly valves so located to control all sources of water supply except
# 264 fire department connections.  Where there is more than one control valve, provide permanently marked
# 265 identification signs indicating the portion of the system controlled by each valve.
# 266 Install flow switches in each zone as indicated on the drawings.
# 267 Install check valves in each water supply connection.
# 268 Alarm Check Valves:  Install valves in the vertical position, in proper direction of flow including the bypass check
# 269 valve and retard chamber drain line connection.  Install valve trim in accordance with the valve manufacturer's
# 270 appropriate trim diagram.  Test valve for proper operation.
# 271 3.5.
# 272 SPRINKLER HEAD INSTALLATIONS
# 273 Provide clean room style sprinkler heads in clean rooms, rooms with hard gypsum ceilings, cold rooms, and
# 274 elsewhere as indicated. Do not seal clean room cover, seal sprinkler enclosure above ceiling.
# 275 PAGE : 7
# 276 Use proper tools to prevent damage during installations.
# 277 Install per installation requirements indicated by NFPA 13.
# 278 3.6.
# 279 FIELD QUALITY CONTROL
# 280 Flush, test, and inspect sprinkler piping systems in accordance with NFPA 13.
# 281 Piping Tests:  Conduct piping tests before joints are covered, and after thrust blocks have sufficiently hardened
# 282 for underground piping.  Fill pipeline with water 24 hours prior to testing and apply test pressure to stabilize
# 283 system.
# 284 Hydrostatic Tests:  Test at not less than 200 psi for two (2) hours or at 50 psi above maximum static pressure if it
# 285 is greater than 150 psi.
# 286 Increase pressure in 50 psi increments and inspect each joint between increments.  Hold at test pressure for one
# 287 (1) hour, decrease to zero (0) psi.  Slowly increase again to test pressure and hold for one (1) more hour.
# 288 Operating Tests:  Open and close all valves under system water pressure.
# 289 Replace piping system components, which do not pass the test procedures specified, and retest repaired portion
# 290 of the system.
# 291 3.7.
# 292 ADJUSTING AND CLEANING
# 293 Flushing:  Flush underground mains, lead-in connections to sprinkler risers, and system piping before connection
# 294 is made to sprinklers, or other fire protection system piping.
# 295 Flush at flow rate not less than that indicated in NFPA 24, or at hydraulically calculated water demand rate of the
# 296 system, whichever is greater.
# 297 3.8.
# 298 IDENTIFICATION SIGNS
# 299 Provide all necessary identification signs for piping, control valves, main drain valves, auxiliary drains, test drains
# 300 and all other signs which may be required by NFPA or FM requirements. Refer to Specification 200553 Tagging
# 301 and Identification for pipe labeling requirements.

# %% [markdown]
# ### C. Find Index of PART

# %%
# start = 0
# for i, l in enumerate(final_data.splitlines()):
#     if(l.upper().startswith("PART")):
#         start = i
#         break

# print("PART Starts At - {}".format(start))
# Out:
# PART Starts At - 0

# %% [markdown]
# ### D. Correct Wrong Lines and Mapp Into Final Lines

# %%
final_lines = []
index = -1
for i, line in enumerate(final_data.splitlines()):
    line = line.strip()
    if(line.strip().startswith("PART")):
        final_lines.append(line)
        index = index + 1
    elif(re.search(r"^[0-9]\.[0-9]", line)):
        final_lines.append(line)
        index = index + 1
    elif(re.search(r"^[A-Za-z]\.", line)):
        final_lines.append(line)
        index = index + 1
    elif(re.search(r"^[0-9]+\.", line)):
        final_lines.append(line)
        index = index + 1
    elif(re.search(r"^[0-9]+\)", line)):
        final_lines.append(line)
        index = index + 1
    elif(re.search(r"^[a-z]+\)", line)):
        final_lines.append(line)
        index = index + 1
    else:
        final_lines[index] = final_lines[index] + " " + line

# %%
final_lines
# Out:
# ['PART 1. - GENERAL This specification for the fire protection work is intended to be a performance type specification for the design, furnishing and complete installation of an automatic fire protection sprinkler system for complete coverage of all renovated and new spaces within the contract limits and to conform to the requirements of NFPA 13, this specification, owner’s insurance underwriter, AXA XL, and to the requirements of State and Local Codes and Regulations.',
#  '1.1. SYSTEM DESCRIPTION Fire Protection System shall be a “Wet-Pipe” system employing automatic sprinklers attached to a piping system containing water and connected to a water supply so that water discharges immediately from the sprinkler head opened by fire.  Fire Protection System shall be approved by AXA XL formerly XLGAPS and the local Authority Having Jurisdiction.',
#  "1.2. SUBMITTALS Product Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department connections specified and/or provided. PAGE : 1 Shop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,” and consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction. Submit shop drawings showing piping materials, size, locations, and elevations. Include details of underground structures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and proximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic calculations. Hydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been approved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information, sprinkler system requirements, water supply information including water supply and sprinkler system demand curves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference points corresponding to reference points indicated on shop drawings. Maintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department connection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual. Test Reports and Certificates including “Contractor's Material & Test Certificate for Aboveground Piping” and “Contractor's Material & Test Certificate for Underground Piping” as described in NFPA 13.",
#  "1.3. QUALITY ASSURANCE Regulatory Requirements:  Comply with the requirements of the following codes: FM DS 2-0 Installation Guidelines for Automatic Sprinklers FM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems FM DS 3-0 Hydraulics of Fire Protection Systems NFPA 13 - Standard for the Installation of Sprinkler Systems. NFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances Local Fire Department and Fire Marshall Regulations including hose unit threading requirements. UL and FM Compliance:  Fire protection system materials and components shall be Underwriter's Laboratories listed and labeled, and Factory Mutual approved for the application anticipated. Field Acceptance Test Report Authorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities: State Fire Marshall Local Fire Department Local Building Code Department Factory Mutual Owner’s Insuring Agency",
#  '1.4. EXTRA MATERIALS Valve Wrenches:  Furnish to Owner, two (2) valve wrenches for each type of sprinkler head installed. Sprinkler Heads and Cabinets:  Furnish six (6) extra sprinkler heads of each style included in the project.  Furnish each style with its own sprinkler head cabinet and special wrenches. PAGE : 2',
#  'PART 2. - PRODUCTS',
#  "2.1. ACCEPTABLE MANUFACTURERS Manufacturers:  Except where manufacturers are specifically indicated herein, they are subject to compliance with the requirements of these specifications, products and manufacturers which are listed in Underwriters' Laboratories Publications and Factory Mutual's Approval Guide as acceptable.",
#  '2.2. INSIDE ABOVE GROUND PIPE Steel Pipe:  ASTM A53/A53 M-01 or A135-01, Schedule 40, seamless or ERW, black steel pipe, plain ends for 2" and below. Steel Pipe:  ASTM A53/A53M-01 or A135-01, Schedule 10 [confirm with owner], seamless or ERW, black steel pipe, plain ends for above 2½". Piping with wall thickness below schedule 10 shall not be used.  This includes “Dynaflow” piping. Clean Manufacturing or Support Areas:  Exposed sprinkler piping in these areas shall be schedule 40, 304L stainless steel with threaded or welded connections. No exposed sprinkler piping over 2” will be allowed in these areas.  Refer to HVAC clean classification plans for extent of clean areas.',
#  '2.3. FITTINGS Cast-Iron Threaded Fittings:  ASME B16.4-1998, Class 125 for system pressure up to 175 psi, standard pattern, for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001). Malleable-Iron Threaded Fittings:  ASME B16.3-1998, Class 150 for system pressure up to 175 psi, standard pattern, for threaded joints.  Threads shall conform to ASME B1.20.1-1983 (R2001) Grooved Mechanical Fittings:  ASTM A 536 Amendment 1-00, Grade 65-45-12 ductile iron; ASTM A 47/A47M- 93 (2002) Grade 32510 malleable iron; or ASTM A53/A53M-01, Type F or Types E or S, Grade B fabricated steel fittings with grooves or shoulders designed to accept grooved end couplings. Stainless Steel Threaded Fittings:  ASTM A351, Class 150 for system pressure up to 175 psi stainless steel threaded fittings. Threads shall conform to ASME B1.20.1-1983 (R2001) Cast Iron Flanged Fittings: ASME/ANSI B16.1-1998, Class 125 for system pressure up to 175 psi. Ductile Iron or Steel Flanged Fittings:  ASME/ANSI B16.5-1996, Class 150 for system pressure up to 175 psi. Grooved Mechanical Couplings:  Consist of ductile or malleable iron housing, a synthetic rubber gasket of a central cavity pressure-responsive design, with nuts, bolts, locking pin, locking toggle, or lugs to secure roll- grooved pipe and fittings.',
#  '2.4. JOINING MATERIALS Gasket Materials:  Thickness, material, and type suitable for fluid or gas to be handled, including design temperatures and pressures. PAGE : 3',
#  '2.5. VALVES Gate Valves (Above Ground):  Provide gate valves, UL listed, 175 psi working pressure.  Provide threaded, flanged, hub, or other end configurations to suit size of valve and piping connection.  Valves shall have solid wedge, outside screw and yoke, rising stem.  Valves shall be capable of being repacked under pressure, with valve wide open. Acceptable Manufacturers Crane Valve Nibco Valve Kennedy Valve Check Valves:  Provide check valves as indicated, UL listed, 175 psi working pressure.  Provide swing or wafer type, iron body, bronze or stainless steel mounted with metal-to-metal or rubber-faced checks.  Provide threaded, flanged, or hub end, to suit size and piping connections. Acceptable Manufacturers Fairbanks Co. Kennedy Valve; Div. of ITT Grinnell Valve Co., Inc. Mueller Co. Nibco Inc. Stockham Valves & Fittings Inc.',
#  '2.6. AUTOMATIC SPRINKLERS Automatic Sprinklers:  Fusible link or glass bulb type and style as indicated or required by the application.  Unless otherwise indicated, provide sprinklers with nominal 1/2" discharge orifice and ordinary temperature range. All sprinkler heads shall be UL listed and FM approved. Acceptable Manufacturers Viking Reliable Central/Tyco Automatic Sprinkler Co. Sprinkler heads in cold rooms under shall be dry pendant type unless noted otherwise on drawings. Sprinkler heads in warehouse high bays where the roof/ceiling does not exceed 40’ shall be ESFR type unless noted otherwise on drawings. Sprinkler Finishes:  Provide sprinklers with the following finishes: Finished Spaces:  Sidewall or Pendant sprinkler heads shall be selected to blend in with the ceiling system and color.  Coordinate sprinkler head colors with architect.  Unless otherwise noted sprinklers in office or lab areas shall be semi-recessed type. Unfinished Spaces or Not Exposed to View:  Sidewall or Upright brass finished sprinkler. Clean Room:  Clean room sprinkler shall be concealed type sprinklers unless noted otherwise on drawings. Provide stainless steel sprinkler head cages for sprinkler heads under platforms or within 7’-0” of floors or walkable ceilings. PAGE : 4',
#  '2.7. ALARM DEVICES General:  Types and sizes shall mate and match piping and equipment connections.  Alarm devices shall activate upon the opening of one sprinkler head. Waterflow Switches:  Vane type waterflow detectors shall be installed on the sprinkler system piping as designated on the drawings and/or as specified herein.  Detectors shall be designed for mounting on either vertical or horizontal piping but shall not be mounted in a fitting or within 12” of any fitting that changes the direction of waterflow, and shall have a sensitivity setting to signal any flow of water that equals or exceeds the discharge from one sprinkler head.  Detector switch mechanisms shall incorporate an instantly recycling retard element in the adjustable range of 0 to 70 seconds.  Switches shall have a minimum rated capacity of seven (7) amp 125V AC - .25 amp 24V DC and two (2) normally open contacts and shall be actuated by a polyethylene vane extending into the waterway of the piping.  Detectors shall be weatherproof, dust tight construction and shall provide a ½” conduit entrance and shall be finished in red baked enamel.  Vane waterflow detectors shall be UL listed and FM approved. Supervisory Devices:  Supervisory switches shall be installed on each control valve in sprinkler system. Switches shall be mounted so not to interfere with the normal operation of the valve and shall be adjusted to operate within two (2) revolutions of the valve control or when the stem has moved no more than 1/5 of the distance from its normal position.  The mechanism shall be contained in a weatherproof die cast aluminum housing, which shall provide a 2/4” tapped conduit entrance and incorporate the necessary facilities for minimum rated capacity of 1 amp.  125V AC - 0.25 amp, 24V DC.  The entire installed assembly shall be tamperproof and arranged to cause a switch operation if the housing cover is removed or if the unit is removed from its mounting. Gate valve switches shall be UL listed and FM approved.',
#  '2.8. HANGERS AND SUPPORTS Except as otherwise indicated, provide factory-fabricated piping hangers, supports, riser clamps, rod attachments, building attachments, shields and saddles, of the following MSS types listed, to suit piping systems. Select and apply UL listed and FM approved supports. Select size of hangers and supports to fit pipe size for bare piping. Horizontal-Piping Hangers shall be: Adjustable steel clevis hangers, MSS-SP-69 Type 1; or Adjustable steel band hangers, MSS- SP-69 Type 7; or Adjustable swivel rings, band type, MSS- SP-69 Type 10 Vertical-Piping Clamps shall be two-bolt riser clamps, MSS Type 8. Exposed sprinkler piping in classified process clean rooms shall be Universal Suspension Systems (Sanitech or Behringer), modular clamping system, or equivalent by Swagelok.  Finish shall be blue or other Owner approved color.',
#  '2.9. ACCESSORIES Clamps, Straps, and Washers: Steel, ASTM A 506-04. Rods: Steel, ASTM A 575-96. Rod Couplings: Malleable-iron, ASTM A 197/A19TM-00. Bolts: Steel, ASTM A 307-04. Cast-Iron Washers: Gray-iron, ASTM A 126-04. PAGE : 5 Escutcheons: Shall be chrome plates steel in non-process areas and polished stainless steel in process areas.',
#  '2.10. INSPECTOR’S TEST CONNECTION Provide inspector’s test connections as specified in NFPA 13, at required points for testing each water-flow alarm device.  Special discharge nozzle shall have same size orifice as majority of sprinkler heads installed.',
#  'PART 3. - EXECUTION',
#  '3.1. INSTALLATION OF PIPE AND FITTINGS - INTERIOR Install Schedule 40 steel pipe with cut or rolled grooved ends and grooved mechanical couplings.  Piping under 2" may utilize threaded connections. Install Schedule 10 steel pipe with roll-grooved ends and grooved mechanical couplings for pipe sizes 2” and above. Exposed sprinkler piping in process areas shall have threaded or welded connections.  Exposed threads shall be limited to one thread.',
#  '3.2. PIPING INSTALLATIONS Locations and Arrangements:  In general run piping: • Install sprinkler piping to provide for system drainage in accordance with NFPA 13. • Provide 2” main drain valves at system valves and route 2” drains to approved drain locations. • Install mechanical sleeve seal at piping penetrations in outside walls and structural walls. • Use approved fittings to make all changes in direction, branch takeoffs from mains, and reductions in pipe sizes. • Install unions in pipes 2" and smaller, adjacent to each valve.  Unions are not required on flanged devices or in piping installations using grooved mechanical couplings. • Coordinate sprinkler pipe routing, sprinkler heads and smoke detector locations with all other trades, including HVAC ductwork, lighting, process and plumbing piping, etc.  Where a conflict exists between sprinkler piping and ductwork, process and/or plumbing piping, the sprinkler piping shall be offset to avoid the conflict. • Sprinkler heads shall be installed in the center of a ceiling tile whenever possible.  In general sprinkler heads shall be installed to provide a uniform ceiling appearance whenever possible. Hangers and Supports:  Comply with the latest requirements of NFPA 13 and NFPA 14.  Hanger and support spacing and locations for piping joined with grooved mechanical couplings shall be in accordance with the grooved mechanical coupling manufacturer\'s written instructions, for rigid systems.  Provide protection from damage where subject to earthquake in accordance with NFPA 13. Hangers and Supports for Clean Manufacturing or Support Areas:  Hangers and supports for exposed sprinkler piping in these areas shall meet FDA sanitary requirements for cleanability. Make connections between underground and above-ground piping using an approved transition piece strapped or fastened to prevent separation. Install test connections sized and located in accordance with NFPA 13 complete with shutoff valve.  Test connections may also serve as drain pipes. PAGE : 6 Install pressure gauge on the riser or feed main at or near each test connection.  Provide gauge with a connection not less than 1/4" and having a soft metal seated globe valve, arranged for draining pipe between gauge and valve. Install gauges to permit removal, and where they will not be subject to freezing. Install wall or ceiling escutcheons where exposed sprinkler piping passes through ceilings or walls.',
#  '3.3. PIPE JOINT CONSTRUCTION Welded Joints:  AWS D10.9, Level AR-3. Threaded Joints:  Conform to ANSI B1.20.1-1983 (R2001), tapered pipe threads for field cut threads.  Join pipe, fittings, and valves as follows: • Note the internal length of threads in fittings or valve ends, and proximity of internal seat or wall, to determine how far pipe should be threaded into joint. • Align threads at point of assembly. • Apply appropriate tape or thread compound to the external pipe threads. • Assemble joint to appropriate thread depth.  When using a wrench on valves place the wrench on the valve end into which the pipe is being threaded. Damaged Threads:  Do not use pipe with threads that are corroded or damaged.  If a weld opens during cutting or threading operations, that portion of pipe shall not be used. Flanged Joints:  Align flanges surfaces parallel.  Assemble joints by sequencing bolt tightening to make initial contact of flanges and gaskets as flat and parallel as possible.  Use suitable lubricants on bolt threads.  Tighten bolts gradually and uniformly to appropriate torque specified by the bolt manufacturer. Mechanical Grooved Joints:  Cut or roll grooves on pipe ends dimensionally compatible with the couplings. End Treatment:  After cutting pipe lengths, remove burrs and fins from pipe ends. Plain end fittings shall not be used.',
#  "3.4. VALVE INSTALLATIONS General:  Install fire protection specialty valves, fittings, and specialties in accordance with the manufacturer's written instructions, NFPA 13and the authority having jurisdiction. Valves:  Install supervised-open gate or butterfly valves so located to control all sources of water supply except fire department connections.  Where there is more than one control valve, provide permanently marked identification signs indicating the portion of the system controlled by each valve. Install flow switches in each zone as indicated on the drawings. Install check valves in each water supply connection. Alarm Check Valves:  Install valves in the vertical position, in proper direction of flow including the bypass check valve and retard chamber drain line connection.  Install valve trim in accordance with the valve manufacturer's appropriate trim diagram.  Test valve for proper operation.",
#  '3.5. SPRINKLER HEAD INSTALLATIONS Provide clean room style sprinkler heads in clean rooms, rooms with hard gypsum ceilings, cold rooms, and elsewhere as indicated. Do not seal clean room cover, seal sprinkler enclosure above ceiling. PAGE : 7 Use proper tools to prevent damage during installations. Install per installation requirements indicated by NFPA 13.',
#  '3.6. FIELD QUALITY CONTROL Flush, test, and inspect sprinkler piping systems in accordance with NFPA 13. Piping Tests:  Conduct piping tests before joints are covered, and after thrust blocks have sufficiently hardened for underground piping.  Fill pipeline with water 24 hours prior to testing and apply test pressure to stabilize system. Hydrostatic Tests:  Test at not less than 200 psi for two (2) hours or at 50 psi above maximum static pressure if it is greater than 150 psi. Increase pressure in 50 psi increments and inspect each joint between increments.  Hold at test pressure for one (1) hour, decrease to zero (0) psi.  Slowly increase again to test pressure and hold for one (1) more hour. Operating Tests:  Open and close all valves under system water pressure. Replace piping system components, which do not pass the test procedures specified, and retest repaired portion of the system.',
#  '3.7. ADJUSTING AND CLEANING Flushing:  Flush underground mains, lead-in connections to sprinkler risers, and system piping before connection is made to sprinklers, or other fire protection system piping. Flush at flow rate not less than that indicated in NFPA 24, or at hydraulically calculated water demand rate of the system, whichever is greater.',
#  '3.8. IDENTIFICATION SIGNS Provide all necessary identification signs for piping, control valves, main drain valves, auxiliary drains, test drains and all other signs which may be required by NFPA or FM requirements. Refer to Specification 200553 Tagging and Identification for pipe labeling requirements.']

# %% [markdown]
# ### E. Capture All Heading Present In Data

# %%
heading = []
flag = True
for line in final_lines:
    if(re.search(r"^[0-9]+\.[0-9]", line.strip()) or line.strip().startswith("PART")):
        heading.append(line)
        flag = False
    elif(re.search(r"^[A-Z]\.", line.strip()) and flag):
        heading.append(line)

print(heading)
# Out:
# ['PART 1. - GENERAL This specification for the fire protection work is intended to be a performance type specification for the design, furnishing and complete installation of an automatic fire protection sprinkler system for complete coverage of all renovated and new spaces within the contract limits and to conform to the requirements of NFPA 13, this specification, owner’s insurance underwriter, AXA XL, and to the requirements of State and Local Codes and Regulations.', '1.1. SYSTEM DESCRIPTION Fire Protection System shall be a “Wet-Pipe” system employing automatic sprinklers attached to a piping system containing water and connected to a water supply so that water discharges immediately from the sprinkler head opened by fire.  Fire Protection System shall be approved by AXA XL formerly XLGAPS and the local Authority Having Jurisdiction.', "1.2. SUBMITTALS Product Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department connections specified and/or provided. PAGE : 1 Shop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,” and consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction. Submit shop drawings showing piping materials, size, locations, and elevations. Include details of underground structures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and proximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic calculations. Hydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been approved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information, sprinkler system requirements, water supply information including water supply and sprinkler system demand curves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference points corresponding to reference points indicated on shop drawings. Maintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department connection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual. Test Reports and Certificates including “Contractor's Material & Test Certificate for Aboveground Piping” and “Contractor's Material & Test Certificate for Underground Piping” as described in NFPA 13.", "1.3. QUALITY ASSURANCE Regulatory Requirements:  Comply with the requirements of the following codes: FM DS 2-0 Installation Guidelines for Automatic Sprinklers FM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems FM DS 3-0 Hydraulics of Fire Protection Systems NFPA 13 - Standard for the Installation of Sprinkler Systems. NFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances Local Fire Department and Fire Marshall Regulations including hose unit threading requirements. UL and FM Compliance:  Fire protection system materials and components shall be Underwriter's Laboratories listed and labeled, and Factory Mutual approved for the application anticipated. Field Acceptance Test Report Authorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities: State Fire Marshall Local Fire Department Local Building Code Department Factory Mutual Owner’s Insuring Agency", '1.4. EXTRA MATERIALS Valve Wrenches:  Furnish to Owner, two (2) valve wrenches for each type of sprinkler head installed. Sprinkler Heads and Cabinets:  Furnish six (6) extra sprinkler heads of each style included in the project.  Furnish each style with its own sprinkler head cabinet and special wrenches. PAGE : 2', 'PART 2. - PRODUCTS', "2.1. ACCEPTABLE MANUFACTURERS Manufacturers:  Except where manufacturers are specifically indicated herein, they are subject to compliance with the requirements of these sp ...

# %% [markdown]
# ### F. Capture and Arange Those Heading Which Has SUBMITTAL In It and Create A Pair

# %%
res = list(map(list, zip(heading, heading[1:])))
index_data = []
heading_list = []
for i, data in enumerate(res):
    if(i == 0):
        heading_list.append("PART 1 - GENERAL")
    if("SUBMITTAL" in data[0]): 
        heading_list.append(data)
    if("PART" in data[1]):
        heading_list.append(data[1])

heading_list
# Out:
# ['PART 1 - GENERAL',
#  ["1.2. SUBMITTALS Product Data for each type of sprinkler, valve, piping specialty, fire protection specialty, and fire department connections specified and/or provided. PAGE : 1 Shop Drawings prepared in accordance with FM Data Sheet 2-0 and NFPA 13 identified as “Working Plans,” and consistent with hydraulic calculations, and which have been approved by the authority having jurisdiction. Submit shop drawings showing piping materials, size, locations, and elevations. Include details of underground structures, connections, thrust blocks, and anchors.  Show interface and spatial relationship between piping and proximate structures.  Indicate hydraulic reference points corresponding to reference points indicated in hydraulic calculations. Hydraulic Calculations prepared in accordance with FM Data Sheet 2-0, 3-0, and NFPA 13, which have been approved by the authority having jurisdiction and owner’s insuring agency.  Submit basic design information, sprinkler system requirements, water supply information including water supply and sprinkler system demand curves, and detailed worksheets.  Indicate source of software and version used.  Indicate hydraulic reference points corresponding to reference points indicated on shop drawings. Maintenance Data for each type of sprinkler, valve, piping specialty, fire protection specialty, fire department connection, hose and rack, and hose cabinet specified, for inclusion in operating and maintenance manual. Test Reports and Certificates including “Contractor's Material & Test Certificate for Aboveground Piping” and “Contractor's Material & Test Certificate for Underground Piping” as described in NFPA 13.",
#   "1.3. QUALITY ASSURANCE Regulatory Requirements:  Comply with the requirements of the following codes: FM DS 2-0 Installation Guidelines for Automatic Sprinklers FM DS 2-8 Earthquake Protections for Water-Based Fire Protection Systems FM DS 3-0 Hydraulics of Fire Protection Systems NFPA 13 - Standard for the Installation of Sprinkler Systems. NFPA 24 - Standard for the Installation of Private Service Mains and their Appurtenances Local Fire Department and Fire Marshall Regulations including hose unit threading requirements. UL and FM Compliance:  Fire protection system materials and components shall be Underwriter's Laboratories listed and labeled, and Factory Mutual approved for the application anticipated. Field Acceptance Test Report Authorities Having Jurisdiction:  Comply with the requirements of the following applicable authorities: State Fire Marshall Local Fire Department Local Building Code Department Factory Mutual Owner’s Insuring Agency"],
#  'PART 2. - PRODUCTS',
#  'PART 3. - EXECUTION']

# %% [markdown]
# ### G. Create Index List Of Start Index and End Index Of Submittal Headinga Including PART

# %%
data_lines = []
if(len(heading_list) == 0):
    final_lines = []
else:
    for item in heading_list:
        if("SUMMITAL" in item or "SUBMITTAL" in item[0] or "SUBMITTALS" in item[0]):
            x, y = final_lines.index(item[0]), final_lines.index(item[1])
            data_lines.append((x, y))
        elif("PART " in item):
            data_lines.append(item)

print(data_lines)
# Out:
# ['PART 1 - GENERAL', (15, 17), (17, 21), 'PART 2 - PRODUCTS – NOT APPLICABLE', 'PART 3 - EXECUTION']

# %% [markdown]
# ### H. Generate Final Lines For Mapping Into Dictionary

# %%
dataset = []
for pos in data_lines:
    if("PART" in pos):
        dataset.append(pos)
    else:
        for ll in range(pos[0], pos[1]):
            dataset.append(final_lines[ll])

print(dataset)
# Out:
# ['PART 1 - GENERAL', '1.5 ACTION SUBMITTALS', 'A. Submit proposals for purchase of products or systems included in allowances in the form specified for Change Orders. PAGE : 1', '1.6 INFORMATIONAL SUBMITTALS', 'A. Submit invoices or delivery slips to show actual quantities of materials delivered to the site for use in fulfillment of each allowance.', 'B. Submit time sheets and other documentation to show labor time and cost for installation of allowance items that include installation as part of the allowance.', 'C. Coordinate and process submittals for allowance items in same manner as for other portions of the Work.', 'PART 2 - PRODUCTS – NOT APPLICABLE', 'PART 3 - EXECUTION']

# %% [markdown]
# ## Step 4 - Map Into Dictionary

# %%
## Map Text Data Into Dictionary
#
dictionary = {}
part_name = ""
cnt = 0
cnt2 = 0

for index, line in enumerate(dataset): 
    if(index == 0):
        dictionary["SECTION"] = spec_number
        head = "SECTION_NAME"
        dictionary[head] = spec_name
        head = "Submittals"
        dictionary[head] = []
        if(line.startswith("PART ")):
            part_name = line
    elif(line.startswith("PART ")):
        part_name = line
    elif(re.search(r"^[0-9]+\.[0-9]+", line)):
        subsection_name = line.split()[0]
        subsection_heading = " ".join(line.split()[1:])
    elif(re.search(r"^[A-Z]\.", line)):
        dictionary[head].append({"Part" : part_name})
        dictionary[head][cnt]["Sub Section"] = subsection_name + " " + line.split(".")[0]
        dictionary[head][cnt]["Sub Section Heading "] = subsection_heading
    
        dictionary[head][cnt]["Submittal Description"] = [line]
        cnt2 = cnt
        cnt = cnt + 1
    elif(re.search(r"^[0-9]+\.", line)):
        try:
            dictionary[head][cnt2]["Submittal Description"].append(line)   
        except Exception as e:
            cnt2 = cnt
            cnt = cnt + 1
            dictionary[head].append({"Part" : part_name})
            dictionary[head][cnt2]["Sub Section"] = subsection_name
            dictionary[head][cnt2]["Sub Section Heading "] = subsection_heading
            # dictionary[head][cnt2]["Submittal Type "] = "NA"
            dictionary[head][cnt2]["Submittal Description"] = [line]
    elif(re.search(r"^[a-z]\.", line)):    
        dictionary[head][cnt2]["Submittal Description"].append(line)
    elif(re.search(r"^[0-9]+\)", line)):     
        dictionary[head][cnt2]["Submittal Description"].append(line)
    elif(re.search(r"^[a-z]+\)", line)):
        dictionary[head][cnt2]["Submittal Description"].append(line)
    elif(len(line.strip()) > 0):
        dictionary[head][cnt2]["Submittal Description"].append(line)
    else:
        pass
    

print(dictionary)
# Out:
# {'SECTION': '012100', 'SECTION_NAME': 'NA', 'Submittals': [{'Part': 'PART 1 - GENERAL', 'Sub Section': '1.5 A', 'Sub Section Heading ': 'ACTION SUBMITTALS', 'Submittal Description': ['A. Submit proposals for purchase of products or systems included in allowances in the form specified for Change Orders. PAGE : 1']}, {'Part': 'PART 1 - GENERAL', 'Sub Section': '1.6 A', 'Sub Section Heading ': 'INFORMATIONAL SUBMITTALS', 'Submittal Description': ['A. Submit invoices or delivery slips to show actual quantities of materials delivered to the site for use in fulfillment of each allowance.']}, {'Part': 'PART 1 - GENERAL', 'Sub Section': '1.6 B', 'Sub Section Heading ': 'INFORMATIONAL SUBMITTALS', 'Submittal Description': ['B. Submit time sheets and other documentation to show labor time and cost for installation of allowance items that include installation as part of the allowance.']}, {'Part': 'PART 1 - GENERAL', 'Sub Section': '1.6 C', 'Sub Section Heading ': 'INFORMATIONAL SUBMITTALS', 'Submittal Description': ['C. Coordinate and process submittals for allowance items in same manner as for other portions of the Work.']}]}

# %% [markdown]
# ## Step 5 - Generate JSON/CSV File

# %% [markdown]
# #### A. Create CSV File

# %%
## Create CSV output from dictionary
#
def create_csv_output(dictionary1, big_spec_name, spec_number, spec_name):
    headlines = ['SECTION', 'SECTION_NAME', 'PART', 'SUB SECTION', 'SUB SECTION HEADING','DECRIPTION']

    big_spec_name = big_spec_name + ".csv"
    file_status = path.exists(big_spec_name)

    with open(big_spec_name, 'a', encoding = 'UTF8', newline = '') as file:
        writer = csv.writer(file)
        if(not file_status):
            writer.writerow(headlines)
        for key, item in dictionary1.items():
            if(isinstance(item, list)):
                for dicti in item:
                    writer.writerow([spec_number, spec_name, dicti['Part'], dicti['Sub Section'], dicti['Sub Section Heading '], " \n".join(it for it in dicti['Submittal Description'])])

# %%
## Function Call - Generate JSON Output With Data
# 
# create_json_output(dictionary, 1, spec_number, spec_name, file_name)

dictionary1 = dictionary

big_spec_name = "YYY"
spec_number = spec_number
spec_name = spec_name
## Function Call - Generate CSV Output With Data
#
create_csv_output(dictionary1, big_spec_name, spec_number, spec_name)

# %% [markdown]
# #### B. Create JSON File

# %%
output_file = str(big_spec_name) + ".json"

with open(output_file, "w", encoding = 'utf-8') as outfile:
    json.dump(dictionary, outfile, indent = 4, ensure_ascii = False)

# %% [markdown]
# ## Step 6 - Add Predictive Model

# %%
## Load Saved Model, Vectorizer and Encoder
#
with open("ML Model/vectorizer.pickle", 'rb+') as file:
    vectorizer_saved = pickle.load(file)

with open("ML Model/label_encoder.pickle", 'rb+') as file:
    encorder_saved = pickle.load(file)

with open("ML Model/type_classifier.pickle", 'rb+') as file:
    classifier_saved = pickle.load(file)

# %%
da = vectorizer_saved.transform(["NA"])
classifier_saved.predict(da)
# Out:
# array([4])

# %%
## Load Prepated Data Data
#
new_dataset = pd.read_csv("YYY.csv")
new_dataset.head()
# Out:
#     SECTION                                     SECTION_NAME  \
# 0  27 05 29  HANGERS AND SUPPORTS FOR COMMUNICATIONS SYSTEMS
# 1  27 05 29  HANGERS AND SUPPORTS FOR COMMUNICATIONS SYSTEMS
#
#                 PART SUB SECTION                    SUB SECTION HEADING  \
# 0   PART 1 - GENERAL      1.03 A                             SUBMITTALS
# 1  PART 2 - PRODUCTS      2.02 A  STRUCTURAL SUPPORT SYSTEMS SUBMITTALS
#
#                                           DECRIPTION
# 0  A. Refer to Section 27 05 00 for requirements ...
# 1  A. Slotted strut supports \n1. Acceptable manu...

# %%
description_vector = vectorizer_saved.transform(new_dataset['DECRIPTION'])
predictions = classifier_saved.predict(description_vector)
new_dataset['TYPE'] = encorder_saved.inverse_transform(predictions)
new_dataset = new_dataset[['SECTION', 'SECTION_NAME', 'PART', 'SUB SECTION', 'SUB SECTION HEADING', 'TYPE','DECRIPTION']]
new_dataset.to_csv("YYY_Updated.csv", index = False)

# %% [markdown]
# ## END - Convert Notebook to Python, PDF

# %%
# !jupyter nbconvert --to script "submittal_extraction_v9.ipynb"
# Out:
# [NbConvertApp] Converting notebook submittal_extraction_v8.ipynb to script
# [NbConvertApp] Writing 10120 bytes to submittal_extraction_v8.py

# %%
# !jupyter nbconvert --to PDFviaHTML "submittal_extraction_v9.ipynb"
# Out:
# [NbConvertApp] Converting notebook submittal_extraction_v9.ipynb to PDFviaHTML
# [NbConvertApp] Writing 189718 bytes to submittal_extraction_v9.pdf

# %% [markdown]
# # Banned Zone - Testing
